# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', 10)     # Show all rows
pd.set_option('display.max_colwidth', None)  # Show full column width
ddi_path = '../../data/ddi.csv'

# %%
import xml.etree.ElementTree as ET

def process_drugbank_to_dataframe(file_path):
    # Parse the XML file
    tree = ET.parse(file_path)
    root = tree.getroot()

    # Namespace as defined in the schema
    namespace = {'ns': 'http://www.drugbank.ca'}

    # Create a list to store the data
    data = []

    # Iterate over all drugs
    for drug in root.findall('ns:drug', namespace):
        # Get the primary drugbank-id
        primary_id = None
        for drugbank_id in drug.findall('ns:drugbank-id', namespace):
            if drugbank_id.attrib.get('primary') == 'true':
                primary_id = drugbank_id.text
                break

        # If no primary ID is found, skip this drug entry
        if not primary_id:
            continue

        # Extract name and description
        name = drug.find('ns:name', namespace)
        description = drug.find('ns:description', namespace)
        primary_name = name.text if name is not None else 'N/A'
        primary_description = description.text if description is not None else 'N/A'

        # Extract drug interactions
        interactions = drug.find('ns:drug-interactions', namespace)
        if interactions:
            for interaction in interactions.findall('ns:drug-interaction', namespace):
                interacting_drug_id = interaction.find('ns:drugbank-id', namespace).text
                interacting_drug_name = interaction.find('ns:name', namespace).text
                interaction_description = interaction.find('ns:description', namespace).text

                # Append the data for interaction
                data.append({
                    'primary_id': primary_id,
                    'primary_name': primary_name,
                    'primary_description': primary_description,
                    'interacting_drug_id': interacting_drug_id,
                    'interacting_drug_name': interacting_drug_name,
                    'interaction_description': interaction_description
                })

    # Create a DataFrame from the data
    df = pd.DataFrame(data)

    # Create a multi-indexed DataFrame
    multi_index_df = df.set_index(['primary_id', 'interacting_drug_id'])

    return multi_index_df


# Example usage
file_path = '../../data/drugbank.xml'
ddi = process_drugbank_to_dataframe(file_path)
ddi = ddi.reset_index()

# %%
ddi.to_csv(ddi_path)

# %%
ddi = pd.read_csv(ddi_path)
ddi
# Out:
#          Unnamed: 0 primary_id interacting_drug_id    primary_name  \
# 0                 0    DB00001             DB06605       Lepirudin
# 1                 1    DB00001             DB06695       Lepirudin
# 2                 2    DB00001             DB01254       Lepirudin
# 3                 3    DB00001             DB01609       Lepirudin
# 4                 4    DB00001             DB01586       Lepirudin
# ...             ...        ...                 ...             ...
# 2839605     2839605    DB18716             DB13328  Enmetazobactam
# 2839606     2839606    DB18716             DB13578  Enmetazobactam
# 2839607     2839607    DB18716             DB13683  Enmetazobactam
# 2839608     2839608    DB18716             DB00565  Enmetazobactam
# 2839609     2839609    DB18716             DB17743  Enmetazobactam
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    primary_description  \
# 0        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 1        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 2        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 3        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 4        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2839605                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839606                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839607                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839608                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839609                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
#
#         interacting_drug_name  \
# 0                    Apixaban
# 1        Dabigatran etexilate
# 2                   Dasatinib
# 3                 Deferasirox
# 4        Ursodeoxycholic acid
# ...                       ...
# 2839605         Butanilicaine
# 2839606       Metabutethamine
# 2839607          Quinisocaine
# 2839608         Cisatracurium
# 2839609      Fecal microbiota
#
#                                                                                                       interaction_description
# 0                                                            Apixaban may increase the anticoagulant activities of Lepirudin.
# 1                                                Dabigatran etexilate may increase the anticoagulant activities of Lepirudin.
# 2                 The risk or severity of bleeding and hemorrhage can be increased when Dasatinib is combined with Lepirudin.
# 3             The risk or severity of gastrointestinal bleeding can be increased when Lepirudin is combined with Deferasirox.
# 4        The risk or severity of bleeding and bruising can be increased when Lepirudin is combined with Ursodeoxycholic acid.
# ...                                                                                                                       ...
# 2839605        The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Butanilicaine.
# 2839606      The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Metabutethamine.
# 2839607         The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Quinisocaine.
# 2839608                                   Enmetazobactam may increase the neuromuscular blocking activities of Cisatracurium.
# 2839609           The therapeutic efficacy of Fecal microbiota can be decreased when used in combination with Enmetazobactam.
#
# [2839610 rows x 7 columns]

# %%
ddi.columns
# Out:
# Index(['Unnamed: 0', 'primary_id', 'interacting_drug_id', 'primary_name',
#        'primary_description', 'interacting_drug_name',
#        'interaction_description'],
#       dtype='object')

# %%
len(ddi['primary_id'].unique())
# Out:
# 4532

# %%
from tqdm import tqdm
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModel
from sklearn.cluster import KMeans

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load BioBERT tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-v1.1")
model = AutoModel.from_pretrained("dmis-lab/biobert-v1.1").to(device)  # Move model to GPU

# Sample drug-drug interaction texts
texts = ddi['interaction_description'].to_list()

# Function to generate embeddings in batches (GPU enabled)
def get_embeddings_in_batches(texts, batch_size=32):
    embeddings = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Processing batches"):
        batch_texts = texts[i:i+batch_size]  # Get batch
        tokens = tokenizer(batch_texts, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)  # Move tokens to GPU
        with torch.no_grad():
            outputs = model(**tokens)
        # Use [CLS] token embeddings (first token of each sequence in batch)
        batch_embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()  # Move back to CPU for further processing
        embeddings.append(batch_embeddings)
    return np.vstack(embeddings)  # Combine all batches

# Generate embeddings in batches
embeddings = get_embeddings_in_batches(texts, batch_size=32)

# Perform clustering using KMeans
n_clusters = 3  # Number of clusters (e.g., synergistic, additive, antagonistic)
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(embeddings)

# Map cluster labels to interaction types (you can assign these based on observation)
interaction_types = {0: "synergistic", 1: "additive", 2: "antagonistic"}

# %%
ddi['labels'] = labels
ddi['label_meaning'] = [interaction_types[i] for i in labels]
ddi

# %%
ddi.to_csv(ddi_path)

# %%
ddi = pd.read_csv(ddi_path)
ddi
# Out:
#          Unnamed: 0.1  Unnamed: 0 primary_id interacting_drug_id  \
# 0                   0           0    DB00001             DB06605
# 1                   1           1    DB00001             DB06695
# 2                   2           2    DB00001             DB01254
# 3                   3           3    DB00001             DB01609
# 4                   4           4    DB00001             DB01586
# ...               ...         ...        ...                 ...
# 2839605       2839605     2839605    DB18716             DB13328
# 2839606       2839606     2839606    DB18716             DB13578
# 2839607       2839607     2839607    DB18716             DB13683
# 2839608       2839608     2839608    DB18716             DB00565
# 2839609       2839609     2839609    DB18716             DB17743
#
#            primary_name  \
# 0             Lepirudin
# 1             Lepirudin
# 2             Lepirudin
# 3             Lepirudin
# 4             Lepirudin
# ...                 ...
# 2839605  Enmetazobactam
# 2839606  Enmetazobactam
# 2839607  Enmetazobactam
# 2839608  Enmetazobactam
# 2839609  Enmetazobactam
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    primary_description  \
# 0        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 1        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 2        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 3        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# 4        Lepirudin is a recombinant hirudin formed by 65 amino acids that acts as a highly specific and direct thrombin inhibitor.[L41539,L41569] Natural hirudin is an endogenous anticoagulant found in _Hirudo medicinalis_ leeches.[L41539] Lepirudin is produced in yeast cells and is identical to natural hirudin except for the absence of sulfate on the tyrosine residue at position 63 and the substitution of leucine for isoleucine at position 1 (N-terminal end).[A246609] \r\n\r\nLepirudin is used as an anticoagulant in patients with heparin-induced thrombocytopenia (HIT), an immune reaction associated with a high risk of thromboembolic complications.[A3, L41539] HIT is caused by the expression of immunoglobulin G (IgG) antibodies that bind to the complex formed by heparin and platelet factor 4. This activates endothelial cells and platelets and enhances the formation of thrombi.[A246609] Bayer ceased the production of lepirudin (Refludan) effective May 31, 2012.[L41574]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2839605                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839606                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839607                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839608                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
# 2839609                                                                                                                                                                                                                                                                                                                                                                                           Enmetazobactam is a penicillanic acid sulfone extended-spectrum beta (β)-lactamase (ESBL) inhibitor.[A263266] Because ESBL enzymes can hydrolyze important antibiotics such as penicillins, broad-spectrum cephalosporins and monobactams, ESBL-producing bacteria poses challenges in the treatment of serious infections.[A263276] \r\n\r\nThe combination product of enmetazobactam and [cefepime] was first approved by the FDA on February 23, 2024, for the treatment of complicated urinary tract infections.[L50126] Enmetazobactam is used as cefepime-sparing therapy by preventing its breakdown by ESBL.
#
#         interacting_drug_name  \
# 0                    Apixaban
# 1        Dabigatran etexilate
# 2                   Dasatinib
# 3                 Deferasirox
# 4        Ursodeoxycholic acid
# ...                       ...
# 2839605         Butanilicaine
# 2839606       Metabutethamine
# 2839607          Quinisocaine
# 2839608         Cisatracurium
# 2839609      Fecal microbiota
#
#                                                                                                       interaction_description  \
# 0                                                            Apixaban may increase the anticoagulant activities of Lepirudin.
# 1                                                Dabigatran etexilate may increase the anticoagulant activities of Lepirudin.
# 2                 The risk or severity of bleeding and hemorrhage can be increased when Dasatinib is combined with Lepirudin.
# 3             The risk or severity of gastrointestinal bleeding can be increased when Lepirudin is combined with Deferasirox.
# 4        The risk or severity of bleeding and bruising can be increased when Lepirudin is combined with Ursodeoxycholic acid.
# ...                                                                                                                       ...
# 2839605        The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Butanilicaine.
# 2839606      The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Metabutethamine.
# 2839607         The risk or severity of methemoglobinemia can be increased when Enmetazobactam is combined with Quinisocaine.
# 2839608                                   Enmetazobactam may increase the neuromuscular blocking activities of Cisatracurium.
# 2839609           The therapeutic efficacy of Fecal microbiota can be decreased when used in combination with Enmetazobactam.
#
#          labels label_meaning
# 0             2  antagonistic
# 1             2  antagonistic
# 2             1      additive
# 3             1      additive
# 4             1      additive
# ...         ...           ...
# 2839605       1      additive
# 2839606       1      additive
# 2839607       1      additive
# 2839608       2  antagonistic
# 2839609       0   synergistic
#
# [2839610 rows x 10 columns]
